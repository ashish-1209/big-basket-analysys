# %% [markdown]
# # Big Basket Mini Project Analysis

# %% [markdown]
# # Import Liabary

# %% [markdown]
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns
# import plotly.express as px
# import warnings
# warnings.filterwarnings('ignore')

# %% [markdown]
# #Load DataSet

# %%
df = pd.read_csv("BigBasket Products.csv")

# %%
df
# Out:
#        index                                            product  \
# 0          1             Garlic Oil - Vegetarian Capsule 500 mg
# 1          2                              Water Bottle - Orange
# 2          3                     Brass Angle Deep - Plain, No.2
# 3          4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4          5                 Creme Soft Soap - For Hands & Body
# ...      ...                                                ...
# 27550  27551         Wottagirl! Perfume Spray - Heaven, Classic
# 27551  27552                                           Rosemary
# 27552  27553                       Peri-Peri Sweet Potato Chips
# 27553  27554                          Green Tea - Pure Original
# 27554  27555                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# ...

# %% [markdown]
# #Use head function to look for first 12 rows.

# %%
df.head(13)
# Out:
#     index                                            product  \
# 0       1             Garlic Oil - Vegetarian Capsule 500 mg
# 1       2                              Water Bottle - Orange
# 2       3                     Brass Angle Deep - Plain, No.2
# 3       4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4       5                 Creme Soft Soap - For Hands & Body
# 5       6                  Germ - Removal Multipurpose Wipes
# 6       7                                       Multani Mati
# 7       8                  Hand Sanitizer - 70% Alcohol Base
# 8       9  Biotin & Collagen Volumizing Hair Shampoo + Bi...
# 9      10               Scrub Pad - Anti- Bacterial, Regular
# 10     11                           Wheat Grass Powder - Raw
# 11     12                     Butter Cookies Gold Collection
# 12     13                    Face Wash - Oil Control, Active
#
#                   category            sub_category              brand  \
# ...

# %% [markdown]
# #Get Description of the data in the DataFrame

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        index                                            product  \
# 0          1             Garlic Oil - Vegetarian Capsule 500 mg
# 1          2                              Water Bottle - Orange
# 2          3                     Brass Angle Deep - Plain, No.2
# 3          4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4          5                 Creme Soft Soap - For Hands & Body
# ...      ...                                                ...
# 27550  27551         Wottagirl! Perfume Spray - Heaven, Classic
# 27551  27552                                           Rosemary
# 27552  27553                       Peri-Peri Sweet Potato Chips
# 27553  27554                          Green Tea - Pure Original
# 27554  27555                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# ...

# %% [markdown]
# #Find Information about the DataFrame.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27555 entries, 0 to 27554
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   index         27555 non-null  int64
#  1   product       27554 non-null  object
#  2   category      27555 non-null  object
#  3   sub_category  27555 non-null  object
#  4   brand         27554 non-null  object
#  5   sale_price    27549 non-null  float64
#  6   market_price  27555 non-null  float64
#  7   type          27555 non-null  object
#  8   rating        18919 non-null  float64
#  9   description   27440 non-null  object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 2.1+ MB

# %% [markdown]
# #Find out Top &amp; least sold products.

# %%
df['product'].value_counts()
# Out:
# product
# Turmeric Powder/Arisina Pudi                                     26
# Extra Virgin Olive Oil                                           15
# Cow Ghee/Tuppa                                                   14
# Soft Drink                                                       12
# Colorsilk Hair Colour With Keratin                               12
#                                                                  ..
# Pepper & Herb Salami Chicken                                      1
# Nutmeg Powder                                                     1
# Disney Mickey Mouse Plastic Kids Sipper Bottle - Coolest Dude     1
# Chocolates-Roasted Peanut Chocolate                               1
# Green Tea - Pure Original                                         1
# Name: count, Length: 23540, dtype: int64

# %% [markdown]
# #Measuring discount on a certain item.

# %%
df.Discount_Price='sale_price-Market_Price'

# %%
df
# Out:
#        index                                            product  \
# 0          1             Garlic Oil - Vegetarian Capsule 500 mg
# 1          2                              Water Bottle - Orange
# 2          3                     Brass Angle Deep - Plain, No.2
# 3          4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4          5                 Creme Soft Soap - For Hands & Body
# ...      ...                                                ...
# 27550  27551         Wottagirl! Perfume Spray - Heaven, Classic
# 27551  27552                                           Rosemary
# 27552  27553                       Peri-Peri Sweet Potato Chips
# 27553  27554                          Green Tea - Pure Original
# 27554  27555                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# ...

# %% [markdown]
# #Find out the Missing Values from the Dataset.

# %%
df.isnull().sum()
# Out:
# index              0
# product            1
# category           0
# sub_category       0
# brand              1
# sale_price         6
# market_price       0
# type               0
# rating          8636
# description      115
# dtype: int64

# %% [markdown]
# #Find out the outliers from the dataset according tothe columns
# and fill them with the mean.

# %%
Q1,Q3 = df.market_price.quantile([0.25,0.75])
Q1,Q3
# Out:
# (100.0, 425.0)

# %%
IQR = Q3 - Q1
IQR
# Out:
# 325.0

# %%
UL = Q3 + 1.5 * (IQR)
LL = Q1 - 1.5 * (IQR)

# %%
UL
# Out:
# 912.5

# %%
LL
# Out:
# -387.5

# %%
Q1,Q3 = df.sale_price.quantile([0.25,0.75])
Q1,Q3
# Out:
# (95.0, 359.0)

# %%
IQR = Q3 - Q1
IQR
# Out:
# 264.0

# %%
UL = Q3 + 1.5 * (IQR)
LL = Q1 - 1.5 * (IQR)

# %%
UL
# Out:
# 755.0

# %%
LL
# Out:
# -301.0

# %%
Q1,Q3 = df.rating.quantile([0.25,0.75])
Q1,Q3
# Out:
# (3.7, 4.3)

# %%
IQR = Q3 - Q1
IQR
# Out:
# 0.5999999999999996

# %%
UL = Q3 + 1.5 * (IQR)
LL = Q1 - 1.5 * (IQR)

# %%
UL
# Out:
# 5.199999999999999

# %%
LL
# Out:
# 2.8000000000000007

# %%
df.mean
# Out:
# <bound method DataFrame.mean of        index                                            product  \
# 0          1             Garlic Oil - Vegetarian Capsule 500 mg
# 1          2                              Water Bottle - Orange
# 2          3                     Brass Angle Deep - Plain, No.2
# 3          4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4          5                 Creme Soft Soap - For Hands & Body
# ...      ...                                                ...
# 27550  27551         Wottagirl! Perfume Spray - Heaven, Classic
# 27551  27552                                           Rosemary
# 27552  27553                       Peri-Peri Sweet Potato Chips
# 27553  27554                          Green Tea - Pure Original
# 27554  27555                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# ...

# %%
df.describe()
# Out:
#              index     sale_price  market_price        rating
# count  27555.00000   27549.000000  27555.000000  18919.000000
# mean   13778.00000     334.648391    382.056664      3.943295
# std     7954.58767    1202.102113    581.730717      0.739217
# min        1.00000       2.450000      3.000000      1.000000
# 25%     6889.50000      95.000000    100.000000      3.700000
# 50%    13778.00000     190.320000    220.000000      4.100000
# 75%    20666.50000     359.000000    425.000000      4.300000
# max    27555.00000  112475.000000  12500.000000      5.000000

# %%
df.sale_price.mean()
# Out:
# 334.6483912301717

# %%
df.market_price.mean()
# Out:
# 382.05666448920346

# %%
df.rating.mean()
# Out:
# 3.9432951001638563

# %%
df.sale_price =np.where(df.sale_price,UL>LL,df.sale_price)

# %%
df
# Out:
#        index                                            product  \
# 0          1             Garlic Oil - Vegetarian Capsule 500 mg
# 1          2                              Water Bottle - Orange
# 2          3                     Brass Angle Deep - Plain, No.2
# 3          4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4          5                 Creme Soft Soap - For Hands & Body
# ...      ...                                                ...
# 27550  27551         Wottagirl! Perfume Spray - Heaven, Classic
# 27551  27552                                           Rosemary
# 27552  27553                       Peri-Peri Sweet Potato Chips
# 27553  27554                          Green Tea - Pure Original
# 27554  27555                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# ...

# %%
df.market_price =np.where(df.market_price<UL,LL,df.market_price)

# %%
df
# Out:
#        index                                            product  \
# 0          1             Garlic Oil - Vegetarian Capsule 500 mg
# 1          2                              Water Bottle - Orange
# 2          3                     Brass Angle Deep - Plain, No.2
# 3          4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4          5                 Creme Soft Soap - For Hands & Body
# ...      ...                                                ...
# 27550  27551         Wottagirl! Perfume Spray - Heaven, Classic
# 27551  27552                                           Rosemary
# 27552  27553                       Peri-Peri Sweet Potato Chips
# 27553  27554                          Green Tea - Pure Original
# 27554  27555                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# ...

# %%
df.rating =np.where(df.rating,UL<LL,df.rating)

# %%
df
# Out:
#        index                                            product  \
# 0          1             Garlic Oil - Vegetarian Capsule 500 mg
# 1          2                              Water Bottle - Orange
# 2          3                     Brass Angle Deep - Plain, No.2
# 3          4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4          5                 Creme Soft Soap - For Hands & Body
# ...      ...                                                ...
# 27550  27551         Wottagirl! Perfume Spray - Heaven, Classic
# 27551  27552                                           Rosemary
# 27552  27553                       Peri-Peri Sweet Potato Chips
# 27553  27554                          Green Tea - Pure Original
# 27554  27555                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# ...

# %%
df.describe()
# Out:
#              index  sale_price  market_price        rating
# count  27555.00000     27555.0  27555.000000  18919.000000
# mean   13778.00000         1.0    382.054821      3.943295
# std     7954.58767         0.0    581.731916      0.739217
# min        1.00000         1.0      2.800000      1.000000
# 25%     6889.50000         1.0    100.000000      3.700000
# 50%    13778.00000         1.0    220.000000      4.100000
# 75%    20666.50000         1.0    425.000000      4.300000
# max    27555.00000         1.0  12500.000000      5.000000

# %%
df.market_price.mean()
# Out:
# 382.0548209036472

# %%
df.sale_price.mean()
# Out:
# 1.0

# %%
df.rating.mean()
# Out:
# 3.9432951001638563

# %%
df[df.market_price>20000]
# Out:
# Empty DataFrame
# Columns: [index, product, category, sub_category, brand, sale_price, market_price, type, rating, description]
# Index: []

# %%
df[1249:]
# Out:
#        index                                     product  \
# 1249    1250                                   Beard Kit
# 1250    1251                                  Baby Cream
# 1251    1252                      Vacuum Fried Jackfruit
# 1252    1253                          Namkeen - Congress
# 1253    1254                     Hand Wash - Orange Peel
# ...      ...                                         ...
# 27550  27551  Wottagirl! Perfume Spray - Heaven, Classic
# 27551  27552                                    Rosemary
# 27552  27553                Peri-Peri Sweet Potato Chips
# 27553  27554                   Green Tea - Pure Original
# 27554  27555              United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 1249         Beauty & Hygiene            Men's Grooming
# 1250                Baby Care       Baby Bath & Hygiene
# 1251     Gourmet & World Food  Snacks, Dry Fruits, Nuts
# ...

# %% [markdown]
# #Create Plots or visualizations.

# %%
sns.boxplot(df.sale_price)
# Out:
# <Axes: >

# %%
sns.boxplot(df.market_price)
# Out:
# <Axes: >

# %%
sns.boxplot(df.rating)
# Out:
# <Axes: >
